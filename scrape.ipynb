# %%
import re

import pandas as pd
import requests
import unidecode
from bs4 import BeautifulSoup
from scrape import *

# %reload_ext autoreload
# %autoreload 2

# %%
jobs = get_jobs_info()
jobs
# Out:
#                                                  title  \
# 0                            Officier Conduite Mission
# 1                 Technicien Interception Des Signaux
# 2                     Technicien Renseignement Images
# 3                    Technicien Renseignement Réseaux
# 4             Technicien Télécommunication Et Réseaux
# ..                                                 ...
# 236  Secrétaire Général Du Comité D'Éthique De La D...
# 237                      Technicien Métiers De L'Image
# 238             Photographe / Vidéaste / Infographiste
# 239                                  Moniteur De Sport
# 240                                      Aide-Soignant
#
#                                                   link        level
# 0    https://devenir-aviateur.fr/rejoindre-la-commu...        BAC+3
# 1    https://devenir-aviateur.fr/devenir/nos-metier...  BAC ET PLUS
# 2    https://devenir-aviateur.fr/devenir/nos-metier...  BAC ET PLUS
# ...

# %%
# Concurrently get job descriptions
with ThreadPoolExecutor(max_workers=32) as executor:
  jobs["text"] = executor.map(get_job_text, jobs["link"])
jobs
# Out:
# Getting job description 241
# Getting job description 242
# Getting job description 243
# Getting job description 244
# Getting job description 245
# Getting job description 246
# Getting job description 247
# Getting job description 248
# Getting job description 249
# Getting job description 250
# Getting job description 251
# Getting job description 252
# Getting job description 253
# Getting job description 254
# Getting job description 255
# Getting job description 256
# Getting job description 257
# Getting job description 258
# Getting job description 259
# Getting job description 260
# Getting job description 261
# Getting job description 262
# Getting job description 263
# Getting job description 264
# Getting job description 265
# Getting job description 266
# Getting job description 267
# Getting job description 268
# Getting job description 269
# Getting job description 270
# Getting job description 271
# Getting job description 272
# Getting job description 273
# ...

# %%
jobs.loc[:, "descr"] = jobs.loc[:, "link"].apply(get_job_text)
# Out:
# Getting job description 0
# Getting job description 1
# Getting job description 2
# Getting job description 3
# Getting job description 4
# Getting job description 5
# Getting job description 6
# Getting job description 7
# Getting job description 8
# Getting job description 9
# Getting job description 10
# Getting job description 11
# Getting job description 12
# Getting job description 13
# Getting job description 14
# Getting job description 15
# Getting job description 16
# Getting job description 17
# Getting job description 18
# Getting job description 19
# Getting job description 20
# Getting job description 21
# Getting job description 22
# Getting job description 23
# Getting job description 24
# Getting job description 25
# Getting job description 26
# Getting job description 27
# Getting job description 28
# Getting job description 29
# Getting job description 30
# Getting job description 31
# Getting job description 32
# Getting job description 33
# ...

# %%
jobs["decoded_descr"] = jobs["descr"].apply(process_descr)
jobs["contains_strong_kw"] = jobs["decoded_descr"].apply(contains_strong_kw)
jobs[jobs["contains_strong_kw"].apply(len) > 0]
# Out:
#                                                  title  \
# 93                          Ingénieur Projets Big Data
# 109  Responsable Des Référentiels D'Aide À La Décision
# 132                                Expert De La Donnée
# 133                                Expert De La Donnée
# 134                                Expert De La Donnée
#
#                                                   link        level  \
# 93   https://devenir-aviateur.fr/rejoindre-la-commu...        BAC+3
# 109  https://devenir-aviateur.fr/rejoindre-la-commu...        BAC+3
# 132  https://devenir-aviateur.fr/rejoindre-la-commu...  BAC à BAC+2
# 133  https://devenir-aviateur.fr/rejoindre-la-commu...  BAC à BAC+2
# 134  https://devenir-aviateur.fr/rejoindre-la-commu...  BAC à BAC+2
#
#                                                  descr  \
# 93   Cyber-Sécurité/Télécommunications\n\n\nIngénie...
# 109  Cyber-Sécurité/Télécommunications\n\n\nRespons...
# ...
